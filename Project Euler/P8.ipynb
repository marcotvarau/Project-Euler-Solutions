# %%
input_str = ('73167176531330624919225119674426574742355349194934\n'
             '96983520312774506326239578318016984801869478851843\n'
             '85861560789112949495459501737958331952853208805511\n'
             '12540698747158523863050715693290963295227443043557\n'
             '66896648950445244523161731856403098711121722383113\n'
             '62229893423380308135336276614282806444486645238749\n'
             '30358907296290491560440772390713810515859307960866\n'
             '70172427121883998797908792274921901699720888093776\n'
             '65727333001053367881220235421809751254540594752243\n'
             '52584907711670556013604839586446706324415722155397\n'
             '53697817977846174064955149290862569321978468622482\n'
             '83972241375657056057490261407972968652414535100474\n'
             '82166370484403199890008895243450658541227588666881\n'
             '16427171479924442928230863465674813919123162824586\n'
             '17866458359124566529476545682848912883142607690042\n'
             '24219022671055626321111109370544217506941658960408\n'
             '07198403850962455444362981230987879927244284909188\n'
             '84580156166097919133875499200524063689912560717606\n'
             '05886116467109405077541002256983155200055935729725\n'
             '71636269561882670428252483600823257530420752963450')

# Remove quebras de linha
cleaned_str = input_str.replace('\n', '')

# Encontrar todas as cadeias de 30 dígitos consecutivos que não contêm '0'
length = 13
sequences = [cleaned_str[i:i+length] for i in range(len(cleaned_str) - length + 1)
             if '0' not in cleaned_str[i:i+length]]

# Printar todas as sequências encontradas
for seq in sequences:
    print(seq)
# Out:
# 7316717653133
# 6249192251196
# 2491922511967
# 4919225119674
# 9192251196744
# 1922511967442
# 9225119674426
# 2251196744265
# 2511967442657
# 5119674426574
# 1196744265747
# 1967442657474
# 9674426574742
# 6744265747423
# 7442657474235
# 4426574742355
# 4265747423553
# 2657474235534
# 6574742355349
# 5747423553491
# 7474235534919
# 4742355349194
# 7423553491949
# 4235534919493
# 2355349194934
# 3553491949349
# 5534919493496
# 5349194934969
# 3491949349698
# 4919493496983
# 9194934969835
# 1949349698352
# 6326239578318
# 1869478851843
# 8694788518438
# 6947885184385
# 9478851843858
# 4788518438586
# 7885184385861
# 8851843858615
# 8518438586156
# 7891129494954
# 8911294949545
# 9112949495459
# 1129494954595
# 1737958331952
# 7379583319528
# 3795833195285
# 7958331952853
# 9583319528532
# 6987471585238
# 9874715852386
# 8747158523863
# 4355766896648
# 3557668966489
# 5576689664895
# 4452445231617
# 4524452316173
# 5244523161731
# 2445231617318
# 4452316173185
# 4523161731856
# ...

# %%
list_of_lists = [[int(char) for char in seq] for seq in sequences]

# %%
maior = 0
for lista in list_of_lists:
    if np.prod(lista,dtype = np.uint64)> maior:
        maior = np.prod(lista,dtype = np.uint64)

# %%
maior
# Out:
# 23514624000
